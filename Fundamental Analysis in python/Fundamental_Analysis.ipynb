# %%
'''
Fundamental Analysis using python
'''
# Out:
# '\nFundamental Analysis using python\n'

# %%
import sqlalchemy
import yfinance as yf
import pandas as pd
print('done')
# Out:
# done

# %%
tickers = pd.read_html(
'https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')[1]

# %%
tickers = tickers.Symbol.to_list()
# Out:
# ['MMM', 'AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CVX', 'CSCO', 'KO', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'MCD', 'MRK', 'MSFT', 'NKE', 'PG', 'CRM', 'TRV', 'UNH', 'VZ', 'V', 'WBA', 'WMT', 'DIS']

# %%
df = pd.DataFrame()

# %%
for ticker in tickers:
    var = yf.Ticker(ticker).info
    frame = pd.DataFrame([var])
    df = df.append(frame)
print('done')
# Out:
# done

# %%
engine = sqlalchemy.create_engine('sqlite:///Fundamentals.db')
print('done')
# Out:
# done

# %%
subdf = df[['symbol','dividendYield','sector','shortRatio','forwardPE','trailingPE']]

# %%
subdf.to_sql('Fundamentalstable',engine,index=False) 
print('done')
# Out:
# done

# %%
pd.read_sql('Fundamentalstable',engine,index_col=['symbol'])
# Out:
#         dividendYield                  sector  shortRatio  forwardPE  \
# symbol
# MMM            0.0337             Industrials        3.47  16.829384
# AXP            0.0099      Financial Services        2.29  17.813830
# AMGN           0.0341              Healthcare        4.34  11.387585
# AAPL           0.0062              Technology        1.18  24.661478
# BA                NaN             Industrials        0.89  37.496620
# CAT            0.0230             Industrials        2.23  17.680672
# CVX            0.0500                  Energy        1.57  13.080803
# CSCO           0.0273              Technology        2.09  14.865123
# KO             0.0310      Consumer Defensive        2.17  22.300411
# DOW            0.0481         Basic Materials        2.09   9.286527
# GS             0.0207      Financial Services        1.86  10.130388
# HD             0.0195       Consumer Cyclical        3.14  22.358746
# HON            0.0182             Industrials        2.45  23.533844
# IBM            0.0467              Technology        7.16  11.919560
# INTC           0.0266              Technology        3.01  11.812941
# JNJ            0.0269              Healthcare        2.64  15.295586
# JPM            0.0228      Financial Services        2.10  13.476171
# MCD            0.0214       Consumer Cyclical        3.09  25.269070
# MRK            0.0345              Healthcare        1.71  11.854791
# MSFT           0.0076              Technology        1.99  35.170680
# NKE            0.0083       Consumer Cyclical        2.10  39.416245
# PG             0.0241      Consumer Defensive        3.07  23.853780
# CRM               NaN              Technology        3.63  67.893974
# TRV            0.0224      Financial Services        4.26  12.666939
# UNH            0.0139              Healthcare        2.96  18.924192
# VZ             0.0455  Communication Services        3.29   9.882978
# V              0.0057      Financial Services        2.94  31.110638
# WBA            0.0360              Healthcare        2.61   9.158301
# WMT            0.0152      Consumer Defensive        2.00  22.172523
# DIS               NaN  Communication Services        2.86  34.161354
# MMM            0.0321             Industrials        3.47  16.771482
# AXP            0.0105      Financial Services        2.73  18.382526
